# %% [markdown]
# # NTF Value Prediction (CSCI-4850 Project)

# %% [markdown]
# Grayscale model

# %% [markdown]
# ## Setup

# %%
import tensorflow.keras as keras
from tensorflow.keras import backend as K
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from random import randint
import os
from PIL import Image
import json
import urllib
# %matplotlib inline

# %%
ETH_API = 'https://api.coinbase.com/v2/exchange-rates?currency=ETH'

ETH_SYM = 'Ξ'
USD_SYM = '$'
BTC_SYM = '₿'

with urllib.request.urlopen(ETH_API) as data:
    C_EXCHANGE = json.load(data)['data']['rates']

def exchange(amt: float, frm: str, to: str = None):
    if to is None:
        return amt * float(C_EXCHANGE[frm])
    else:
        return amt / float(C_EXCHANGE[frm]) * float(C_EXCHANGE[to])

def dollars(val: float):
    return f'{USD_SYM} {val:,.2f}'

def eths(val: float):
    return f'{val:,.4f} {ETH_SYM}'

def coins(val: float):
    return f'{val:,.4f} {BTC_SYM}'

print(f"current rate ({ETH_SYM}->{USD_SYM}) {dollars(exchange(1.0, 'USD'))}")
print(f"current rate ({USD_SYM}->{ETH_SYM}) {eths(exchange(1.0, 'USD', 'ETH'))}")

print(f"current rate ({ETH_SYM}->{BTC_SYM}) {coins(exchange(1.0, 'BTC'))}")
print(f"current rate ({BTC_SYM}->{ETH_SYM}) {eths(exchange(1.0, 'BTC', 'ETH'))}")
# Out:
# current rate (Ξ->$) $ 2,875.17
# current rate ($->Ξ) 0.0003 Ξ
# current rate (Ξ->₿) 0.0736 ₿
# current rate (₿->Ξ) 13.5953 Ξ

# %%
acceptable = ('.jpg','.jpeg','.bmp','.png')

preferred_size = (128, 128)

X = []
XG = []
Y1 = []
Y2 = []

for root, dirs, files in os.walk("./Nft dataset"):
    for name in filter(lambda x: x.endswith(acceptable), files):
        full_path = os.path.join(root, name)
        print(f'found {repr(full_path)}')
        temp = Image.open(full_path)
        print(f'\timage dimensions: {temp.size}')
        if temp.size != preferred_size:
            print(f'\tresizing...')
            temp = temp.resize(preferred_size, Image.LANCZOS)
            print(f'\tnew image dimensions: {temp.size}')
        temp = temp.convert("RGB") 
        arr = np.array(temp)
        print(f'\tarray shape: {arr.shape}')
        X.append(arr)
        temp = temp.convert("L") 
        arr = np.array(temp)
        arr = np.array([[[k] for k in v] for v in arr])
        print(f'\tarray shape: {arr.shape}')
        XG.append(arr)
        val = float(name.rsplit('.', 1)[0].rsplit(' ', 1)[0])
        print(f'\tvalue: {eths(val)}')
        Y1.append(val)
        Y2.append(0.0)
        print()

X = np.array(X)
XG = np.array(XG)
Y1 = np.array(Y1)
Y2 = np.array(Y2)
        
print(X.shape)
print(Y1.shape)
print(Y2.shape)
# Out:
# found './Nft dataset/1.169.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.1690 Ξ
#
# found './Nft dataset/0.2987.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.2987 Ξ
#
# found './Nft dataset/7.02.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 7.0200 Ξ
#
# found './Nft dataset/12.25.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 12.2500 Ξ
#
# found './Nft dataset/2.498.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.4980 Ξ
#
# found './Nft dataset/10.5.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 10.5000 Ξ
#
# found './Nft dataset/6.5.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 6.5000 Ξ
#
# found './Nft dataset/27.47.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 27.4700 Ξ
#
# found './Nft dataset/0.2313.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.2313 Ξ
#
# found './Nft dataset/1.02.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.0200 Ξ
#
# found './Nft dataset/17.619.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 17.6190 Ξ
#
# found './Nft dataset/0.9.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.9000 Ξ
#
# found './Nft dataset/16.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 16.0000 Ξ
#
# found './Nft dataset/0.777.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.7770 Ξ
#
# found './Nft dataset/17.45.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 17.4500 Ξ
#
# found './Nft dataset/1.5661.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.5661 Ξ
#
# found './Nft dataset/34.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 34.0000 Ξ
#
# found './Nft dataset/13.97.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 13.9700 Ξ
#
# found './Nft dataset/0.76.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.7600 Ξ
#
# found './Nft dataset/1.289.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.2890 Ξ
#
# found './Nft dataset/0.879.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.8790 Ξ
#
# found './Nft dataset/13.5.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 13.5000 Ξ
#
# found './Nft dataset/.949.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.9490 Ξ
#
# found './Nft dataset/24.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 24.0000 Ξ
#
# found './Nft dataset/18.69.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.6900 Ξ
#
# found './Nft dataset/14.535.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 14.5350 Ξ
#
# found './Nft dataset/0.2821.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.2821 Ξ
#
# found './Nft dataset/15.9.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 15.9000 Ξ
#
# found './Nft dataset/0.3149.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.3149 Ξ
#
# found './Nft dataset/1.466.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.4660 Ξ
#
# found './Nft dataset/11.1.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 11.1000 Ξ
#
# found './Nft dataset/2.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.0000 Ξ
#
# found './Nft dataset/1.3989.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.3989 Ξ
#
# found './Nft dataset/15.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 15.0000 Ξ
#
# found './Nft dataset/16.01.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 16.0100 Ξ
#
# found './Nft dataset/0.84.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.8400 Ξ
#
# found './Nft dataset/0.889.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.8890 Ξ
#
# found './Nft dataset/1.42.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.4200 Ξ
#
# found './Nft dataset/2.6.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.6000 Ξ
#
# found './Nft dataset/1.035.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.0350 Ξ
#
# found './Nft dataset/42.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 42.0000 Ξ
#
# found './Nft dataset/1.39.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.3900 Ξ
#
# found './Nft dataset/0.2777.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.2777 Ξ
#
# found './Nft dataset/13.84.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 13.8400 Ξ
#
# found './Nft dataset/18.51.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.5100 Ξ
#
# found './Nft dataset/17.77.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 17.7700 Ξ
#
# found './Nft dataset/0.33.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.3300 Ξ
#
# found './Nft dataset/1.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.0000 Ξ
#
# found './Nft dataset/11.19.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 11.1900 Ξ
#
# found './Nft dataset/1.3879.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.3879 Ξ
#
# found './Nft dataset/0.8.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.8000 Ξ
#
# found './Nft dataset/10.25.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 10.2500 Ξ
#
# found './Nft dataset/2.65.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.6500 Ξ
#
# found './Nft dataset/18.45.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.4500 Ξ
#
# found './Nft dataset/0.2346.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.2346 Ξ
#
# found './Nft dataset/2.55.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.5500 Ξ
#
# found './Nft dataset/2.01.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.0100 Ξ
#
# found './Nft dataset/37.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 37.0000 Ξ
#
# found './Nft dataset/1.5645.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.5645 Ξ
#
# found './Nft dataset/26.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 26.0000 Ξ
#
# found './Nft dataset/0.3014.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.3014 Ξ
#
# found './Nft dataset/13.48.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 13.4800 Ξ
#
# found './Nft dataset/1.71.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.7100 Ξ
#
# found './Nft dataset/12.69.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 12.6900 Ξ
#
# found './Nft dataset/40.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 40.0000 Ξ
#
# found './Nft dataset/41.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 41.0000 Ξ
#
# found './Nft dataset/0.25.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.2500 Ξ
#
# found './Nft dataset/39.97.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 39.9700 Ξ
#
# found './Nft dataset/36.969.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 36.9690 Ξ
#
# found './Nft dataset/1.148.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.1480 Ξ
#
# found './Nft dataset/9.18.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 9.1800 Ξ
#
# found './Nft dataset/4.69.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 4.6900 Ξ
#
# found './Nft dataset/10.6.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 10.6000 Ξ
#
# found './Nft dataset/26.69.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 26.6900 Ξ
#
# found './Nft dataset/14.42.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 14.4200 Ξ
#
# found './Nft dataset/21.57.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 21.5700 Ξ
#
# found './Nft dataset/2.749.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.7490 Ξ
#
# found './Nft dataset/24.87.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 24.8700 Ξ
#
# found './Nft dataset/11.8853.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 11.8853 Ξ
#
# found './Nft dataset/12.5.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 12.5000 Ξ
#
# found './Nft dataset/11.28.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 11.2800 Ξ
#
# found './Nft dataset/25.55.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 25.5500 Ξ
#
# found './Nft dataset/2.122.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.1220 Ξ
#
# found './Nft dataset/0.3.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.3000 Ξ
#
# found './Nft dataset/20.349.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 20.3490 Ξ
#
# found './Nft dataset/17.95.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 17.9500 Ξ
#
# found './Nft dataset/13.84 (2).png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 13.8400 Ξ
#
# found './Nft dataset/28.99.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 28.9900 Ξ
#
# found './Nft dataset/2.47.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.4700 Ξ
#
# found './Nft dataset/15.1.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 15.1000 Ξ
#
# found './Nft dataset/0.929.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.9290 Ξ
#
# found './Nft dataset/1.239.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.2390 Ξ
#
# found './Nft dataset/14.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 14.0000 Ξ
#
# found './Nft dataset/18.1.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.1000 Ξ
#
# found './Nft dataset/1.72.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.7200 Ξ
#
# found './Nft dataset/17.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 17.0000 Ξ
#
# found './Nft dataset/0.95.jpg'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.9500 Ξ
#
# found './Nft dataset/18.49.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.4900 Ξ
#
# found './Nft dataset/25.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 25.0000 Ξ
#
# found './Nft dataset/2.7.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.7000 Ξ
#
# found './Nft dataset/0.95.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.9500 Ξ
#
# found './Nft dataset/1.8731.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 1.8731 Ξ
#
# found './Nft dataset/12.75.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 12.7500 Ξ
#
# found './Nft dataset/14.5.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 14.5000 Ξ
#
# found './Nft dataset/11.47.png'
# 	image dimensions: (600, 600)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 11.4700 Ξ
#
# found './Nft dataset/18.39.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.3900 Ξ
#
# found './Nft dataset/17.33.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 17.3300 Ξ
#
# found './Nft dataset/2.4.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 2.4000 Ξ
#
# found './Nft dataset/0.824.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 0.8240 Ξ
#
# found './Nft dataset/18.png'
# 	image dimensions: (286, 286)
# 	resizing...
# 	new image dimensions: (128, 128)
# 	array shape: (128, 128, 3)
# 	array shape: (128, 128, 1)
# 	value: 18.0000 Ξ
#
# (110, 128, 128, 3)
# (110,)
# (110,)

# %%
class ModelInfo:
    def __init__(self, weights, epochs=None):
        self.weights = weights
        self.epochs = epochs

    def load_model(self, model):
        model.set_weights(self.weights)
        
    def store_model(self, model, epochs=None):
        self.epochs = epochs if epochs is not None else self.epochs
        self.weights = model.get_weights()

class ModelHistory:
    def __init__(self):
        self.history = []
    
    def __iter__(self):
        return iter(self.history)
    
    def stash_model(self, model, epochs=None):
        self.history.append(ModelInfo(model.get_weights(), epochs))
        
def extend_history(old=None, new=None):
    if old is None:
        return new
    else:
        oh, nh = old.history, new.history
        for key in nh:
            if key in oh:
                oh[key].extend(nh[key])
            else:
                oh[key] = list(nh[key])
        return old

# %% [markdown]
# ## Model Creation

# %%
x = keras.layers.Input(XG.shape[1:], name="Input_Layer")
y = x
y = keras.layers.Conv2D(128, kernel_size=(8,8), activation='relu', name="First_Convolution")(y)
y = keras.layers.Conv2D(64, kernel_size=(6,6), activation='relu', name="Second_Convolution")(y)
y = keras.layers.Conv2D(32, kernel_size=(4,4), activation='relu', name="Third_Convolution")(y)
y = keras.layers.MaxPooling2D(pool_size=(8,8), name="Max_Pooling")(y)
y = keras.layers.Dropout(0.05)(y)
y = keras.layers.Flatten()(y)
z = keras.layers.Dense(128, activation='relu')(y)
#y = keras.layers.Dense(128, activation='relu')(y)

stack = 2
for _ in range(stack):
    a = keras.layers.Dense(128, activation='relu')(z)
    #b = keras.layers.Dense(128, activation='relu')(y)
    c = keras.layers.Add()([a, z])
    #d = keras.layers.Add()([b, y])
    #z, y = c, d
    z = c
# y = keras.layers.LayerNormalization()(y)
# Output Logits (10)
a = keras.layers.Dense(1, name="ETH_Val")(z) # Ethereum value of the NFT
#y = keras.layers.Dense(1, activation='sigmoid', name="Rug_Prob")(y) # Whether or not the NFT will "rug" (scam its buyers)
z = a
#model = keras.Model(x,[z, y],name="NFT_Valuator")
model = keras.Model(x,z,name="NFT_Valuator")
generator = keras.preprocessing.image.ImageDataGenerator(
    width_shift_range=0.05,
    height_shift_range=0.05,
    rotation_range=4,
    zoom_range=0.1
)
#model.compile(
#    loss={'ETH_Val': keras.losses.MeanSquaredError(), 'Rug_Prob': keras.losses.BinaryCrossentropy()},
#    optimizer=keras.optimizers.Adam(),
#    metrics={'ETH_Val': keras.metrics.MeanSquaredError(), 'Rug_Prob': keras.metrics.BinaryAccuracy()}
#)
model.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(),
    metrics=keras.metrics.MeanAbsoluteError()
)
model.summary()
keras.utils.plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# Model: "NFT_Valuator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input_Layer (InputLayer)        [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# First_Convolution (Conv2D)      (None, 121, 121, 128 8320        Input_Layer[0][0]
# __________________________________________________________________________________________________
# Second_Convolution (Conv2D)     (None, 116, 116, 64) 294976      First_Convolution[0][0]
# __________________________________________________________________________________________________
# Third_Convolution (Conv2D)      (None, 113, 113, 32) 32800       Second_Convolution[0][0]
# __________________________________________________________________________________________________
# Max_Pooling (MaxPooling2D)      (None, 14, 14, 32)   0           Third_Convolution[0][0]
# __________________________________________________________________________________________________
# dropout_97 (Dropout)            (None, 14, 14, 32)   0           Max_Pooling[0][0]
# __________________________________________________________________________________________________
# flatten_52 (Flatten)            (None, 6272)         0           dropout_97[0][0]
# __________________________________________________________________________________________________
# dense_278 (Dense)               (None, 128)          802944      flatten_52[0][0]
# __________________________________________________________________________________________________
# dense_279 (Dense)               (None, 128)          16512       dense_278[0][0]
# __________________________________________________________________________________________________
# add_140 (Add)                   (None, 128)          0           dense_279[0][0]
#                                                                  dense_278[0][0]
# __________________________________________________________________________________________________
# dense_280 (Dense)               (None, 128)          16512       add_140[0][0]
# __________________________________________________________________________________________________
# add_141 (Add)                   (None, 128)          0           dense_280[0][0]
#                                                                  add_140[0][0]
# __________________________________________________________________________________________________
# ETH_Val (Dense)                 (None, 1)            129         add_141[0][0]
# ==================================================================================================
# Total params: 1,172,193
# Trainable params: 1,172,193
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save("NFTValuator")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input_Layer with unsupported characters which will be renamed to input_layer in the SavedModel.
# INFO:tensorflow:Assets written to: NFTValuator/assets
# INFO:tensorflow:Assets written to: NFTValuator/assets
# /opt/conda/lib/python3.9/site-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ## Training

# %%
history = None
model_history = ModelHistory()

# %%
model = keras.models.load_model("NFTValuator")

# %%
batch_size = 32
epochs = 4
trials = 200

hr_w = 80
hr = '-' * hr_w

generator.fit(XG)

for t in range(trials):
    print(hr)
    print(f'TRIAL {t+1:,}'.center(hr_w))
    print(hr)
    history = extend_history(
        history, 
        model.fit(
            generator.flow(XG, Y1, batch_size=batch_size),
            epochs=epochs,
            batch_size=batch_size,
            verbose=1
        )
    )
    model_history.stash_model(model, epochs)
# Out:
# --------------------------------------------------------------------------------
#                                     TRIAL 1
# --------------------------------------------------------------------------------
# Epoch 1/4
# 4/4 [==============================] - 31s 9s/step - loss: 972.4795 - mean_absolute_error: 24.1093
# Epoch 2/4
# 4/4 [==============================] - 36s 10s/step - loss: 548.9238 - mean_absolute_error: 19.0146
# Epoch 3/4

# %%
model.save("NFTValuator")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input_Layer with unsupported characters which will be renamed to input_layer in the SavedModel.
# INFO:tensorflow:Assets written to: NFTValuator/assets
# INFO:tensorflow:Assets written to: NFTValuator/assets
# /opt/conda/lib/python3.9/site-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
plt.figure(1)
# summarize history for accuracy
plt.subplot(211)
plt.plot(history.history['mean_absolute_error'])
#plt.plot(history.history['ETH_Val_mean_squared_error'])
#plt.plot(history.history['Rug_Prob_binary_accuracy'])
plt.ylabel('Negative Accuracy')
plt.xlabel('Epoch')
#plt.legend(['ETH Value','Rug Probability'],loc='lower right')
# summarize history for loss
plt.subplot(212)
plt.plot(history.history['loss'])
#plt.plot(history.history['ETH_Val_loss'])
#plt.plot(history.history['Rug_Prob_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['ETH Value','Rug Probability'],loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ----
# ## Testing the Model

# %% [markdown]
# This step is covered in [Project_Demo.ipynb](../Project_Demo.ipynb)
